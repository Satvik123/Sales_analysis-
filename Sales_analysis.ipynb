# %%
import pandas as pd
import numpy as np

# %%
import os

# %%
files=[file for file in os.listdir(r'c:\Users\hp\Documents\Data analytics\Datasets\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data')]

# %%
amd=pd.DataFrame()
files
# Out:
# ['Sales_April_2019.csv',
#  'Sales_August_2019.csv',
#  'Sales_December_2019.csv',
#  'Sales_February_2019.csv',
#  'Sales_January_2019.csv',
#  'Sales_July_2019.csv',
#  'Sales_June_2019.csv',
#  'Sales_March_2019.csv',
#  'Sales_May_2019.csv',
#  'Sales_November_2019.csv',
#  'Sales_October_2019.csv',
#  'Sales_September_2019.csv']

# %%
for file in files:
  df=pd.read_csv(r'c:\Users\hp\Documents\Data analytics\Datasets\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data\\' + file)
  amd= pd.concat([amd,df])

# %%
amd.head()
amd.tail()
amd.sample(12)
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 2255    152655  Bose SoundSport Headphones                1      99.99
# 1051    177558             ThinkPad Laptop                1     999.99
# 842     223719        USB-C Charging Cable                1      11.95
# 5033    181366        USB-C Charging Cable                1      11.95
# 8530    184710                      iPhone                1        700
# 14189   309203  Bose SoundSport Headphones                1      99.99
# 6495    182762       AA Batteries (4-pack)                3       3.84
# 11722   247879            Wired Headphones                1      11.99
# 2633    281323      27in 4K Gaming Monitor                1     389.99
# 20811      NaN                         NaN              NaN        NaN
# 11131   269981    Lightning Charging Cable                1      14.95
# 10182   269074       AA Batteries (4-pack)                1       3.84
#
#            Order Date                            Purchase Address
# 2255   02/06/19 11:34        413 11th St, San Francisco, CA 94016
# 1051   04/10/19 22:50         990 9th St, San Francisco, CA 94016
# 842    07/31/19 19:17              283 10th St, Seattle, WA 98101
# 5033   04/04/19 18:48          454 14th St, Los Angeles, CA 90001
# 8530   04/21/19 13:57               921 12th St, Dallas, TX 75001
# 14189  12/08/19 21:48       399 North St, New York City, NY 10001
# 6495   04/28/19 16:19            412 Church St, Atlanta, GA 30301
# 11722  08/07/19 16:01           770 Lakeview St, Boston, MA 02215
# 2633   11/17/19 11:48         759 Jefferson St, Atlanta, GA 30301
# 20811             NaN                                         NaN
# 11131  10/02/19 13:20               401 Elm St, Seattle, WA 98101
# 10182  10/22/19 08:50  615 Washington St, San Francisco, CA 94016

# %%
amd['Order Date']=pd.to_datetime(amd['Order Date'],errors='coerce')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_9036\1995902990.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   amd['Order Date']=pd.to_datetime(amd['Order Date'],errors='coerce')

# %%
amd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 186850 entries, 0 to 11685
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        185950 non-null  datetime64[ns]
#  5   Purchase Address  186305 non-null  object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 10.0+ MB

# %%
amd['Month']=amd['Order Date'].dt.month

# %%
amd.sample(22)
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 9817    288180                Google Phone                1        600
# 4427    299874                      iPhone                1        700
# 13116   308183    Lightning Charging Cable                1      14.95
# 14770   309765      34in Ultrawide Monitor                1     379.99
# 6182    167905    Lightning Charging Cable                1      14.95
# 10856   172380    Lightning Charging Cable                1      14.95
# 5039    181371            Wired Headphones                1      11.99
# 12821   271599    Lightning Charging Cable                1      14.95
# 8106    303396       AA Batteries (4-pack)                1       3.84
# 3522    213267    Apple Airpods Headphones                1        150
# 2456    250507      27in 4K Gaming Monitor                1     389.99
# 9709    159775       AA Batteries (4-pack)                1       3.84
# 887     237525               Flatscreen TV                1        300
# 14706   309706       AA Batteries (4-pack)                2       3.84
# 2765    298303            27in FHD Monitor                1     149.99
# 11534   205057  Bose SoundSport Headphones                1      99.99
# 22835   317477            Wired Headphones                1      11.99
# 9081    268024            Wired Headphones                1      11.99
# 7822    244157        USB-C Charging Cable                1      11.95
# 12621   221963       AA Batteries (4-pack)                1       3.84
# 11283   172787        USB-C Charging Cable                1      11.95
# 12373      NaN                         NaN              NaN        NaN
#
#                Order Date                           Purchase Address  Month
# 9817  2019-11-24 21:34:00          112 Cherry St, Portland, OR 97035   11.0
# 4427  2019-12-19 09:47:00             159 Park St, Atlanta, GA 30301   12.0
# 13116 2019-12-11 13:25:00          270 8th St, Los Angeles, CA 90001   12.0
# 14770 2019-12-27 11:40:00        4 Washington St, Portland, OR 97035   12.0
# 6182  2019-03-03 19:37:00     658 Wilson St, San Francisco, CA 94016    3.0
# 10856 2019-03-20 01:35:00           31 4th St, Los Angeles, CA 90001    3.0
# 5039  2019-04-04 12:55:00         93 1st St, San Francisco, CA 94016    4.0
# 12821 2019-10-09 15:49:00     778 Meadow St, San Francisco, CA 94016   10.0
# 8106  2019-12-18 20:21:00          404 Hickory St, Atlanta, GA 30301   12.0
# 3522  2019-06-24 19:59:00             631 Ridge St, Boston, MA 02215    6.0
# 2456  2019-09-03 21:56:00     184 Meadow St, San Francisco, CA 94016    9.0
# 9709  2019-02-02 17:05:00         695 Lakeview St, Atlanta, GA 30301    2.0
# 887   2019-08-05 16:57:00   251 Lakeview St, New York City, NY 10001    8.0
# 14706 2019-12-17 19:46:00       153 Hill St, San Francisco, CA 94016   12.0
# 2765  2019-12-16 21:02:00  547 Jefferson St, San Francisco, CA 94016   12.0
# 11534 2019-05-20 16:12:00             548 8th St, Portland, ME 04101    5.0
# 22835 2019-12-15 16:19:00              268 11th St, Boston, MA 02215   12.0
# 9081  2019-10-03 16:53:00       454 West St, San Francisco, CA 94016   10.0
# 7822  2019-08-05 20:57:00            698 Forest St, Boston, MA 02215    8.0
# 12621 2019-06-14 16:12:00         753 14th St, Los Angeles, CA 90001    6.0
# 11283 2019-03-25 19:11:00           254 Wilson St, Seattle, WA 98101    3.0
# 12373                 NaT                                        NaN    NaN

# %%
amd=amd.dropna()

# %%
amd['Month']=amd['Month'].astype('int32')
amd['Quantity Ordered']=amd['Quantity Ordered'].astype('int32')
amd['Price Each']=amd['Price Each'].astype('float32')

# %%
amd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 185950 entries, 0 to 11685
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int32
#  3   Price Each        185950 non-null  float32
#  4   Order Date        185950 non-null  datetime64[ns]
#  5   Purchase Address  185950 non-null  object
#  6   Month             185950 non-null  int32
# dtypes: datetime64[ns](1), float32(1), int32(2), object(3)
# memory usage: 9.2+ MB

# %%
amd['Sales']=amd['Price Each']*amd['Quantity Ordered']

# %%
amd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 185950 entries, 0 to 11685
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int32
#  3   Price Each        185950 non-null  float32
#  4   Order Date        185950 non-null  datetime64[ns]
#  5   Purchase Address  185950 non-null  object
#  6   Month             185950 non-null  int32
#  7   Sales             185950 non-null  float64
# dtypes: datetime64[ns](1), float32(1), float64(1), int32(2), object(3)
# memory usage: 10.6+ MB

# %%
spm=amd.groupby('Month')['Sales'].sum()
spm
# Out:
# Month
# 1     1.822257e+06
# 2     2.202022e+06
# 3     2.807100e+06
# 4     3.390670e+06
# 5     3.152607e+06
# 6     2.577802e+06
# 7     2.647776e+06
# 8     2.244468e+06
# 9     2.097560e+06
# 10    3.736727e+06
# 11    3.199603e+06
# 12    4.613443e+06
# Name: Sales, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
month=range(1,13)

# %%
plt.bar(month,spm)
plt.xlabel('Months')
plt.ylabel('Sales')
plt.xticks(month)
# Out:
# ([<matplotlib.axis.XTick at 0x23edf724f50>,
#   <matplotlib.axis.XTick at 0x23ede723610>,
#   <matplotlib.axis.XTick at 0x23ede722210>,
#   <matplotlib.axis.XTick at 0x23ede721d10>,
#   <matplotlib.axis.XTick at 0x23ede721950>,
#   <matplotlib.axis.XTick at 0x23ee46825d0>,
#   <matplotlib.axis.XTick at 0x23ee4682490>,
#   <matplotlib.axis.XTick at 0x23ee4683250>,
#   <matplotlib.axis.XTick at 0x23ee46839d0>,
#   <matplotlib.axis.XTick at 0x23ee75fc190>,
#   <matplotlib.axis.XTick at 0x23ee75fc910>,
#   <matplotlib.axis.XTick at 0x23ee75fd090>],
#  [Text(1, 0, '1'),
#   Text(2, 0, '2'),
#   Text(3, 0, '3'),
#   Text(4, 0, '4'),
#   Text(5, 0, '5'),
#   Text(6, 0, '6'),
#   Text(7, 0, '7'),
#   Text(8, 0, '8'),
#   Text(9, 0, '9'),
#   Text(10, 0, '10'),
#   Text(11, 0, '11'),
#   Text(12, 0, '12')])

# %%
amd['City']=amd['Purchase Address'].apply(lambda y: f"{y.split(',')[1]} ({y.split(',')[2].split(' ')[1]})")

# %%
amd.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2   11.950000
# 2   176559  Bose SoundSport Headphones                 1   99.989998
# 3   176560                Google Phone                 1  600.000000
# 4   176560            Wired Headphones                 1   11.990000
# 5   176561            Wired Headphones                 1   11.990000
#
#            Order Date                      Purchase Address  Month  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4
#
#         Sales               City
# 0   23.900000        Dallas (TX)
# 2   99.989998        Boston (MA)
# 3  600.000000   Los Angeles (CA)
# 4   11.990000   Los Angeles (CA)
# 5   11.990000   Los Angeles (CA)

# %%
result=amd.groupby('City')['Sales'].sum()
result
# Out:
# City
# Atlanta (GA)          2.795499e+06
# Austin (TX)           1.819582e+06
# Boston (MA)           3.661642e+06
# Dallas (TX)           2.767975e+06
# Los Angeles (CA)      5.452571e+06
# New York City (NY)    4.664317e+06
# Portland (ME)         4.497583e+05
# Portland (OR)         1.870732e+06
# San Francisco (CA)    8.262204e+06
# Seattle (WA)          2.747755e+06
# Name: Sales, dtype: float64

# %%
cities=[city for city,df in amd.groupby('City')]
cities
# Out:
# [' Atlanta (GA)',
#  ' Austin (TX)',
#  ' Boston (MA)',
#  ' Dallas (TX)',
#  ' Los Angeles (CA)',
#  ' New York City (NY)',
#  ' Portland (ME)',
#  ' Portland (OR)',
#  ' San Francisco (CA)',
#  ' Seattle (WA)']

# %%
plt.bar(cities,result)
plt.xticks(cities,rotation='vertical')
plt.xlabel(cities)
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
amd['Hours']=amd['Order Date'].dt.hour

# %%
result=amd.groupby(amd['Hours']).count()

# %%
result
# Out:
#        Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# Hours
# 0          3910     3910              3910        3910        3910
# 1          2350     2350              2350        2350        2350
# 2          1243     1243              1243        1243        1243
# 3           831      831               831         831         831
# 4           854      854               854         854         854
# 5          1321     1321              1321        1321        1321
# 6          2482     2482              2482        2482        2482
# 7          4011     4011              4011        4011        4011
# 8          6256     6256              6256        6256        6256
# 9          8748     8748              8748        8748        8748
# 10        10944    10944             10944       10944       10944
# 11        12411    12411             12411       12411       12411
# 12        12587    12587             12587       12587       12587
# 13        12129    12129             12129       12129       12129
# 14        10984    10984             10984       10984       10984
# 15        10175    10175             10175       10175       10175
# 16        10384    10384             10384       10384       10384
# 17        10899    10899             10899       10899       10899
# 18        12280    12280             12280       12280       12280
# 19        12905    12905             12905       12905       12905
# 20        12228    12228             12228       12228       12228
# 21        10921    10921             10921       10921       10921
# 22         8822     8822              8822        8822        8822
# 23         6275     6275              6275        6275        6275
#
#        Purchase Address  Month  Sales   City
# Hours
# 0                  3910   3910   3910   3910
# 1                  2350   2350   2350   2350
# 2                  1243   1243   1243   1243
# 3                   831    831    831    831
# 4                   854    854    854    854
# 5                  1321   1321   1321   1321
# 6                  2482   2482   2482   2482
# 7                  4011   4011   4011   4011
# 8                  6256   6256   6256   6256
# 9                  8748   8748   8748   8748
# 10                10944  10944  10944  10944
# 11                12411  12411  12411  12411
# 12                12587  12587  12587  12587
# 13                12129  12129  12129  12129
# 14                10984  10984  10984  10984
# 15                10175  10175  10175  10175
# 16                10384  10384  10384  10384
# 17                10899  10899  10899  10899
# 18                12280  12280  12280  12280
# 19                12905  12905  12905  12905
# 20                12228  12228  12228  12228
# 21                10921  10921  10921  10921
# 22                 8822   8822   8822   8822
# 23                 6275   6275   6275   6275

# %%
hours=[hour for hour,df in amd.groupby(amd['Hours'])]

# %%
plt.plot(hours,result)
plt.xticks(hours)
plt.xlabel('Hours')
plt.ylabel('No. of Orders')
plt.grid()

# %%
df=amd[amd['Order ID'].duplicated(keep=False)]

# %%
df['Grouped']=df.groupby('Order ID')['Product'].transform(lambda x: ', '.join(x))
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_9036\1878607989.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Grouped']=df.groupby('Order ID')['Product'].transform(lambda x: ', '.join(x))

# %%
df.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 3    176560                Google Phone                 1  600.000000
# 4    176560            Wired Headphones                 1   11.990000
# 18   176574                Google Phone                 1  600.000000
# 19   176574        USB-C Charging Cable                 1   11.950000
# 30   176585  Bose SoundSport Headphones                 1   99.989998
#
#             Order Date                      Purchase Address  Month  \
# 3  2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 4  2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 18 2019-04-03 19:42:00     20 Hill St, Los Angeles, CA 90001      4
# 19 2019-04-03 19:42:00     20 Hill St, Los Angeles, CA 90001      4
# 30 2019-04-07 11:31:00     823 Highland St, Boston, MA 02215      4
#
#          Sales               City  Hours  \
# 3   600.000000   Los Angeles (CA)     14
# 4    11.990000   Los Angeles (CA)     14
# 18  600.000000   Los Angeles (CA)     19
# 19   11.950000   Los Angeles (CA)     19
# 30   99.989998        Boston (MA)     11
#
#                                               Grouped
# 3                      Google Phone, Wired Headphones
# 4                      Google Phone, Wired Headphones
# 18                 Google Phone, USB-C Charging Cable
# 19                 Google Phone, USB-C Charging Cable
# 30  Bose SoundSport Headphones, Bose SoundSport He...

# %%
df=df[['Order ID','Grouped']].drop_duplicates()

# %%
df
# Out:
#       Order ID                                            Grouped
# 3       176560                     Google Phone, Wired Headphones
# 18      176574                 Google Phone, USB-C Charging Cable
# 30      176585  Bose SoundSport Headphones, Bose SoundSport He...
# 32      176586               AAA Batteries (4-pack), Google Phone
# 119     176672     Lightning Charging Cable, USB-C Charging Cable
# ...        ...                                                ...
# 11617   259296  Apple Airpods Headphones, Apple Airpods Headph...
# 11619   259297  iPhone, Lightning Charging Cable, Lightning Ch...
# 11627   259303      34in Ultrawide Monitor, AA Batteries (4-pack)
# 11639   259314           Wired Headphones, AAA Batteries (4-pack)
# 11677   259350                 Google Phone, USB-C Charging Cable
#
# [7136 rows x 2 columns]

# %%
from itertools import combinations
from collections import Counter

# %%
count =Counter()

# %%
for row in df['Grouped']:
    row_list=row.split(',')
    count.update(Counter(combinations(row_list,2)))

# %%
count
# Out:
# Counter({('Google Phone', ' USB-C Charging Cable'): 9110,
#          ('iPhone', ' Lightning Charging Cable'): 2010,
#          ('iPhone', ' Wired Headphones'): 894,
#          ('Google Phone', ' Wired Headphones'): 828,
#          ('Vareebadd Phone', ' USB-C Charging Cable'): 722,
#          ('iPhone', ' Apple Airpods Headphones'): 720,
#          ('Google Phone', ' Bose SoundSport Headphones'): 440,
#          ('Vareebadd Phone', ' Wired Headphones'): 286,
#          (' USB-C Charging Cable', ' Wired Headphones'): 240,
#          ('Vareebadd Phone', ' Bose SoundSport Headphones'): 160,
#          (' Lightning Charging Cable', ' Wired Headphones'): 124,
#          ('Lightning Charging Cable', ' USB-C Charging Cable'): 110,
#          ('Lightning Charging Cable', ' AA Batteries (4-pack)'): 104,
#          (' USB-C Charging Cable', ' Bose SoundSport Headphones'): 102,
#          ('Lightning Charging Cable', ' Lightning Charging Cable'): 102,
#          ('AA Batteries (4-pack)', ' Lightning Charging Cable'): 102,
#          ('AAA Batteries (4-pack)', ' USB-C Charging Cable'): 100,
#          ('AA Batteries (4-pack)', ' AAA Batteries (4-pack)'): 96,
#          ('AAA Batteries (4-pack)', ' AAA Batteries (4-pack)'): 96,
#          (' Lightning Charging Cable', ' Apple Airpods Headphones'): 94,
#          ('USB-C Charging Cable', ' USB-C Charging Cable'): 92,
#          ('Apple Airpods Headphones', ' AAA Batteries (4-pack)'): 90,
#          ('AA Batteries (4-pack)', ' Wired Headphones'): 88,
#          ('AAA Batteries (4-pack)', ' Lightning Charging Cable'): 88,
#          ('Google Phone', ' USB-C Charging Cable', ' Wired Headphones'): 87,
#          ('AAA Batteries (4-pack)', ' Wired Headphones'): 86,
#          ('Wired Headphones', ' AAA Batteries (4-pack)'): 86,
#          ('USB-C Charging Cable', ' AAA Batteries (4-pack)'): 84,
#          ('Wired Headphones', ' USB-C Charging Cable'): 84,
#          ('Apple Airpods Headphones', ' Wired Headphones'): 84,
#          ('USB-C Charging Cable', ' Lightning Charging Cable'): 82,
#          ('AA Batteries (4-pack)', ' Apple Airpods Headphones'): 82,
#          ('USB-C Charging Cable', ' Wired Headphones'): 80,
#          ('AAA Batteries (4-pack)', ' AA Batteries (4-pack)'): 78,
#          ('Lightning Charging Cable', ' Bose SoundSport Headphones'): 78,
#          ('Bose SoundSport Headphones', ' AAA Batteries (4-pack)'): 74,
#          ('AA Batteries (4-pack)', ' USB-C Charging Cable'): 74,
#          ('Wired Headphones', ' AA Batteries (4-pack)'): 72,
#          ('Wired Headphones', ' Lightning Charging Cable'): 72,
#          ('Apple Airpods Headphones', ' Lightning Charging Cable'): 70,
#          ('Lightning Charging Cable', ' AAA Batteries (4-pack)'): 70,
#          ('USB-C Charging Cable', ' AA Batteries (4-pack)'): 70,
#          ('AA Batteries (4-pack)', ' AA Batteries (4-pack)'): 70,
#          ('Wired Headphones', ' Wired Headphones'): 68,
#          ('Lightning Charging Cable', ' Apple Airpods Headphones'): 68,
#          ('AAA Batteries (4-pack)', ' Apple Airpods Headphones'): 66,
#          ('Bose SoundSport Headphones', ' Lightning Charging Cable'): 64,
#          ('Apple Airpods Headphones', ' Bose SoundSport Headphones'): 62,
#          ('USB-C Charging Cable', ' Apple Airpods Headphones'): 62,
#          ('iPhone', ' Lightning Charging Cable', ' Wired Headphones'): 62,
#          ('Lightning Charging Cable', ' Wired Headphones'): 60,
#          (' Bose SoundSport Headphones', ' Wired Headphones'): 58,
#          ('Wired Headphones', ' Apple Airpods Headphones'): 58,
#          ('USB-C Charging Cable', ' 27in FHD Monitor'): 58,
#          ('Apple Airpods Headphones', ' USB-C Charging Cable'): 58,
#          ('Apple Airpods Headphones', ' AA Batteries (4-pack)'): 58,
#          ('AA Batteries (4-pack)', ' Bose SoundSport Headphones'): 56,
#          ('Bose SoundSport Headphones', ' Bose SoundSport Headphones'): 54,
#          ('Bose SoundSport Headphones', ' AA Batteries (4-pack)'): 54,
#          (' Apple Airpods Headphones', ' Wired Headphones'): 54,
#          ('USB-C Charging Cable', ' Bose SoundSport Headphones'): 52,
#          ('Bose SoundSport Headphones', ' USB-C Charging Cable'): 50,
#          ('Bose SoundSport Headphones', ' Wired Headphones'): 48,
#          ('Apple Airpods Headphones', ' Apple Airpods Headphones'): 48,
#          ('iPhone',
#           ' Lightning Charging Cable',
#           ' Apple Airpods Headphones'): 47,
#          ('AAA Batteries (4-pack)', ' 27in FHD Monitor'): 44,
#          ('27in FHD Monitor', ' AAA Batteries (4-pack)'): 42,
#          ('Wired Headphones', ' Bose SoundSport Headphones'): 42,
#          ('AAA Batteries (4-pack)', ' Bose SoundSport Headphones'): 40,
#          ('34in Ultrawide Monitor', ' AA Batteries (4-pack)'): 38,
#          ('AA Batteries (4-pack)', ' iPhone'): 36,
#          ('27in FHD Monitor', ' Lightning Charging Cable'): 36,
#          ('Lightning Charging Cable', ' 27in FHD Monitor'): 36,
#          ('34in Ultrawide Monitor', ' Lightning Charging Cable'): 36,
#          ('Google Phone',
#           ' USB-C Charging Cable',
#           ' Bose SoundSport Headphones'): 35,
#          ('iPhone', ' AAA Batteries (4-pack)'): 34,
#          ('Lightning Charging Cable', ' 27in 4K Gaming Monitor'): 34,
#          ('Wired Headphones', ' 34in Ultrawide Monitor'): 34,
#          ('Wired Headphones', ' 27in 4K Gaming Monitor'): 34,
#          ('Bose SoundSport Headphones', ' Apple Airpods Headphones'): 34,
#          ('Vareebadd Phone', ' USB-C Charging Cable', ' Wired Headphones'): 33,
#          ('ThinkPad Laptop', ' AAA Batteries (4-pack)'): 32,
#          ('27in 4K Gaming Monitor', ' Lightning Charging Cable'): 32,
#          ('34in Ultrawide Monitor', ' USB-C Charging Cable'): 30,
#          ('27in FHD Monitor', ' AA Batteries (4-pack)'): 30,
#          ('AAA Batteries (4-pack)', ' 27in 4K Gaming Monitor'): 30,
#          ('iPhone', ' USB-C Charging Cable'): 30,
#          ('20in Monitor', ' USB-C Charging Cable'): 30,
#          ('Lightning Charging Cable', ' 20in Monitor'): 30,
#          ('27in 4K Gaming Monitor', ' AAA Batteries (4-pack)'): 30,
#          ('Google Phone', ' AA Batteries (4-pack)'): 28,
#          ('Lightning Charging Cable', ' Google Phone'): 28,
#          ('AA Batteries (4-pack)', ' 27in 4K Gaming Monitor'): 28,
#          ('AAA Batteries (4-pack)', ' iPhone'): 28,
#          ('Lightning Charging Cable', ' 34in Ultrawide Monitor'): 28,
#          ('iPhone', ' AA Batteries (4-pack)'): 28,
#          ('iPhone', ' Apple Airpods Headphones', ' Wired Headphones'): 27,
#          ('AA Batteries (4-pack)', ' Flatscreen TV'): 26,
#          ('Apple Airpods Headphones', ' Google Phone'): 26,
#          ('Wired Headphones', ' iPhone'): 26,
#          ('Bose SoundSport Headphones', ' 27in FHD Monitor'): 26,
#          ('AA Batteries (4-pack)', ' 34in Ultrawide Monitor'): 26,
#          ('AAA Batteries (4-pack)', ' 34in Ultrawide Monitor'): 26,
#          ('Apple Airpods Headphones', ' iPhone'): 26,
#          ('Apple Airpods Headphones', ' 27in 4K Gaming Monitor'): 24,
#          ('USB-C Charging Cable', ' iPhone'): 24,
#          ('Apple Airpods Headphones', ' 27in FHD Monitor'): 24,
#          ('27in FHD Monitor', ' Bose SoundSport Headphones'): 24,
#          ('27in FHD Monitor', ' USB-C Charging Cable'): 24,
#          ('Google Phone', ' Lightning Charging Cable'): 24,
#          ('Apple Airpods Headphones', ' Macbook Pro Laptop'): 24,
#          ('27in 4K Gaming Monitor', ' USB-C Charging Cable'): 24,
#          ('Macbook Pro Laptop', ' USB-C Charging Cable'): 24,
#          ('20in Monitor', ' Wired Headphones'): 24,
#          ('27in FHD Monitor', ' Apple Airpods Headphones'): 24,
#          ('USB-C Charging Cable', ' Google Phone'): 24,
#          ('27in 4K Gaming Monitor', ' AA Batteries (4-pack)'): 24,
#          ('34in Ultrawide Monitor', ' AAA Batteries (4-pack)'): 24,
#          ('Wired Headphones', ' Macbook Pro Laptop'): 24,
#          ('Google Phone',
#           ' Bose SoundSport Headphones',
#           ' Wired Headphones'): 24,
#          ('AAA Batteries (4-pack)', ' Google Phone'): 22,
#          ('AAA Batteries (4-pack)', ' Macbook Pro Laptop'): 22,
#          ('USB-C Charging Cable', ' 27in 4K Gaming Monitor'): 22,
#          ('USB-C Charging Cable', ' ThinkPad Laptop'): 22,
#          ('34in Ultrawide Monitor', ' Wired Headphones'): 22,
#          ('20in Monitor', ' Lightning Charging Cable'): 22,
#          ('AA Batteries (4-pack)', ' 27in FHD Monitor'): 22,
#          ('ThinkPad Laptop', ' Lightning Charging Cable'): 22,
#          ('Google Phone', ' AAA Batteries (4-pack)'): 22,
#          ('Macbook Pro Laptop', ' Lightning Charging Cable'): 22,
#          ('AA Batteries (4-pack)', ' Google Phone'): 22,
#          ('Wired Headphones', ' 27in FHD Monitor'): 22,
#          ('AAA Batteries (4-pack)', ' ThinkPad Laptop'): 22,
#          ('Lightning Charging Cable', ' Flatscreen TV'): 22,
#          ('Macbook Pro Laptop', ' Bose SoundSport Headphones'): 22,
#          ('27in 4K Gaming Monitor', ' Wired Headphones'): 22,
#          ('Flatscreen TV', ' AAA Batteries (4-pack)'): 22,
#          ('Flatscreen TV', ' Lightning Charging Cable'): 20,
#          ('Wired Headphones', ' ThinkPad Laptop'): 20,
#          ('USB-C Charging Cable', ' 20in Monitor'): 20,
#          ('27in 4K Gaming Monitor', ' Apple Airpods Headphones'): 20,
#          ('Bose SoundSport Headphones', ' 34in Ultrawide Monitor'): 20,
#          ('USB-C Charging Cable', ' Flatscreen TV'): 20,
#          ('27in FHD Monitor', ' Wired Headphones'): 20,
#          ('USB-C Charging Cable', ' 34in Ultrawide Monitor'): 20,
#          ('AA Batteries (4-pack)', ' 20in Monitor'): 20,
#          ('AAA Batteries (4-pack)', ' Flatscreen TV'): 20,
#          ('Lightning Charging Cable', ' Macbook Pro Laptop'): 20,
#          ('Bose SoundSport Headphones', ' 27in 4K Gaming Monitor'): 20,
#          ('Apple Airpods Headphones', ' ThinkPad Laptop'): 18,
#          ('27in 4K Gaming Monitor', ' Bose SoundSport Headphones'): 18,
#          ('20in Monitor', ' Bose SoundSport Headphones'): 18,
#          ('Macbook Pro Laptop', ' AA Batteries (4-pack)'): 18,
#          ('ThinkPad Laptop', ' USB-C Charging Cable'): 18,
#          ('ThinkPad Laptop', ' Bose SoundSport Headphones'): 18,
#          ('Vareebadd Phone', ' AA Batteries (4-pack)'): 18,
#          ('USB-C Charging Cable', ' Macbook Pro Laptop'): 18,
#          ('Lightning Charging Cable', ' iPhone'): 18,
#          ('27in FHD Monitor', ' 27in FHD Monitor'): 18,
#          ('AA Batteries (4-pack)', ' ThinkPad Laptop'): 18,
#          ('Bose SoundSport Headphones', ' Flatscreen TV'): 18,
#          ('Lightning Charging Cable', ' ThinkPad Laptop'): 18,
#          ('Wired Headphones', ' Google Phone'): 16,
#          ('AA Batteries (4-pack)', ' Macbook Pro Laptop'): 16,
#          ('Flatscreen TV', ' AA Batteries (4-pack)'): 16,
#          ('Apple Airpods Headphones', ' Flatscreen TV'): 16,
#          ('ThinkPad Laptop', ' AA Batteries (4-pack)'): 16,
#          ('AAA Batteries (4-pack)', ' 20in Monitor'): 16,
#          ('34in Ultrawide Monitor', ' Apple Airpods Headphones'): 16,
#          ('Bose SoundSport Headphones', ' Google Phone'): 16,
#          ('Vareebadd Phone',
#           ' USB-C Charging Cable',
#           ' Bose SoundSport Headphones'): 16,
#          ('20in Monitor', ' Apple Airpods Headphones'): 14,
#          ('Macbook Pro Laptop', ' Apple Airpods Headphones'): 14,
#          ('Wired Headphones', ' Flatscreen TV'): 14,
#          ('Wired Headphones', ' 20in Monitor'): 14,
#          ('Macbook Pro Laptop', ' Wired Headphones'): 14,
#          ('Google Phone', ' 27in FHD Monitor'): 14,
#          ('Macbook Pro Laptop', ' AAA Batteries (4-pack)'): 14,
#          ('34in Ultrawide Monitor', ' iPhone'): 14,
#          ('34in Ultrawide Monitor', ' 34in Ultrawide Monitor'): 14,
#          ('Flatscreen TV', ' USB-C Charging Cable'): 14,
#          ('Bose SoundSport Headphones', ' iPhone'): 14,
#          ('ThinkPad Laptop', ' Apple Airpods Headphones'): 14,
#          ('Google Phone', ' Apple Airpods Headphones'): 14,
#          ('Macbook Pro Laptop', ' 27in 4K Gaming Monitor'): 14,
#          ('iPhone', ' 27in 4K Gaming Monitor'): 12,
#          ('Flatscreen TV', ' Flatscreen TV'): 12,
#          ('Apple Airpods Headphones', ' 34in Ultrawide Monitor'): 12,
#          ('iPhone', ' 34in Ultrawide Monitor'): 12,
#          ('Vareebadd Phone', ' Apple Airpods Headphones'): 12,
#          ('USB-C Charging Cable', ' Vareebadd Phone'): 12,
#          ('27in 4K Gaming Monitor', ' 34in Ultrawide Monitor'): 12,
#          ('27in 4K Gaming Monitor', ' Macbook Pro Laptop'): 12,
#          ('Bose SoundSport Headphones', ' 20in Monitor'): 12,
#          ('iPhone', ' Flatscreen TV'): 12,
#          ('Apple Airpods Headphones', ' 20in Monitor'): 12,
#          ('Apple Airpods Headphones', ' Vareebadd Phone'): 12,
#          ('Wired Headphones', ' Vareebadd Phone'): 12,
#          ('34in Ultrawide Monitor', ' Bose SoundSport Headphones'): 12,
#          ('Google Phone', ' iPhone'): 12,
#          ('27in FHD Monitor', ' Macbook Pro Laptop'): 12,
#          ('20in Monitor', ' AA Batteries (4-pack)'): 12,
#          ('iPhone', ' Bose SoundSport Headphones'): 10,
#          ('27in 4K Gaming Monitor', ' 27in 4K Gaming Monitor'): 10,
#          ('Flatscreen TV', ' 34in Ultrawide Monitor'): 10,
#          ('27in 4K Gaming Monitor', ' Google Phone'): 10,
#          ('27in FHD Monitor', ' 34in Ultrawide Monitor'): 10,
#          ('Flatscreen TV', ' Apple Airpods Headphones'): 10,
#          ('34in Ultrawide Monitor', ' 27in FHD Monitor'): 10,
#          ('Macbook Pro Laptop', ' 34in Ultrawide Monitor'): 8,
#          ('iPhone', ' Vareebadd Phone'): 8,
#          ('Bose SoundSport Headphones', ' ThinkPad Laptop'): 8,
#          ('20in Monitor', ' Macbook Pro Laptop'): 8,
#          ('Vareebadd Phone', ' 34in Ultrawide Monitor'): 8,
#          ('Flatscreen TV', ' Wired Headphones'): 8,
#          ('Flatscreen TV', ' 27in FHD Monitor'): 8,
#          ('LG Dryer', ' AA Batteries (4-pack)'): 8,
#          ('Flatscreen TV', ' Macbook Pro Laptop'): 8,
#          ('27in FHD Monitor', ' 27in 4K Gaming Monitor'): 8,
#          ('ThinkPad Laptop', ' Flatscreen TV'): 8,
#          ('Flatscreen TV', ' iPhone'): 8,
#          ('27in 4K Gaming Monitor', ' ThinkPad Laptop'): 8,
#          ('Vareebadd Phone', ' Google Phone'): 8,
#          ('Macbook Pro Laptop', ' Google Phone'): 8,
#          ('27in 4K Gaming Monitor', ' 27in FHD Monitor'): 8,
#          ('Lightning Charging Cable', ' LG Washing Machine'): 8,
#          ('27in FHD Monitor', ' ThinkPad Laptop'): 8,
#          ('ThinkPad Laptop', ' Wired Headphones'): 8,
#          ('iPhone', ' ThinkPad Laptop'): 8,
#          ('Bose SoundSport Headphones', ' Macbook Pro Laptop'): 8,
#          ('AAA Batteries (4-pack)', ' Vareebadd Phone'): 8,
#          ('LG Washing Machine', ' AAA Batteries (4-pack)'): 8,
#          (' Apple Airpods Headphones', ' AAA Batteries (4-pack)'): 6,
#          ('Macbook Pro Laptop', ' ThinkPad Laptop'): 6,
#          ('ThinkPad Laptop', ' Google Phone'): 6,
#          (' Wired Headphones', ' USB-C Charging Cable'): 6,
#          ('34in Ultrawide Monitor', ' Macbook Pro Laptop'): 6,
#          (' Lightning Charging Cable', ' Lightning Charging Cable'): 6,
#          ('Google Phone', ' ThinkPad Laptop'): 6,
#          ('20in Monitor', ' 20in Monitor'): 6,
#          ('ThinkPad Laptop', ' iPhone'): 6,
#          ('Vareebadd Phone', ' Flatscreen TV'): 6,
#          ('34in Ultrawide Monitor', ' Flatscreen TV'): 6,
#          ('Macbook Pro Laptop', ' Macbook Pro Laptop'): 6,
#          ('34in Ultrawide Monitor', ' ThinkPad Laptop'): 6,
#          (' Lightning Charging Cable', ' AA Batteries (4-pack)'): 6,
#          (' Wired Headphones', ' AA Batteries (4-pack)'): 6,
#          ('Macbook Pro Laptop', ' iPhone'): 6,
#          ('Vareebadd Phone', ' iPhone'): 6,
#          ('Wired Headphones', ' LG Washing Machine'): 6,
#          ('Google Phone', ' 34in Ultrawide Monitor'): 6,
#          ('Macbook Pro Laptop', ' 27in FHD Monitor'): 6,
#          (' USB-C Charging Cable', ' Apple Airpods Headphones'): 6,
#          ('Flatscreen TV', ' Bose SoundSport Headphones'): 6,
#          ('AA Batteries (4-pack)', ' Vareebadd Phone'): 6,
#          ('27in FHD Monitor', ' 20in Monitor'): 6,
#          ('iPhone', ' Google Phone'): 6,
#          (' USB-C Charging Cable', ' AAA Batteries (4-pack)'): 6,
#          ('27in 4K Gaming Monitor', ' iPhone'): 6,
#          ('Google Phone', ' Google Phone'): 6,
#          (' USB-C Charging Cable', ' AA Batteries (4-pack)'): 6,
#          ('Flatscreen TV', ' Google Phone'): 6,
#          ('Google Phone', ' Macbook Pro Laptop'): 6,
#          ('27in 4K Gaming Monitor', ' Flatscreen TV'): 6,
#          ('Apple Airpods Headphones', ' LG Dryer'): 6,
#          (' Lightning Charging Cable', ' USB-C Charging Cable'): 6,
#          ('20in Monitor', ' AAA Batteries (4-pack)'): 6,
#          ('iPhone', ' Macbook Pro Laptop'): 6,
#          (' USB-C Charging Cable',
#           ' Bose SoundSport Headphones',
#           ' Wired Headphones'): 5,
#          ('Vareebadd Phone',
#           ' Bose SoundSport Headphones',
#           ' Wired Headphones'): 5,
#          ('34in Ultrawide Monitor', ' Google Phone'): 4,
#          (' USB-C Charging Cable', ' USB-C Charging Cable'): 4,
#          ('Macbook Pro Laptop', ' 20in Monitor'): 4,
#          ('Lightning Charging Cable', ' LG Dryer'): 4,
#          ('Flatscreen TV', ' 27in 4K Gaming Monitor'): 4,
#          ('ThinkPad Laptop', ' Macbook Pro Laptop'): 4,
#          (' USB-C Charging Cable', ' 27in FHD Monitor'): 4,
#          ('Macbook Pro Laptop', ' LG Washing Machine'): 4,
#          (' USB-C Charging Cable', ' iPhone'): 4,
#          ('20in Monitor', ' 27in FHD Monitor'): 4,
#          ('ThinkPad Laptop', ' ThinkPad Laptop'): 4,
#          ('Bose SoundSport Headphones', ' Vareebadd Phone'): 4,
#          ('Vareebadd Phone', ' ThinkPad Laptop'): 4,
#          ('20in Monitor', ' ThinkPad Laptop'): 4,
#          (' Wired Headphones', ' Apple Airpods Headphones'): 4,
#          ('Lightning Charging Cable', ' Vareebadd Phone'): 4,
#          ('iPhone', ' iPhone'): 4,
#          (' Wired Headphones', ' iPhone'): 4,
#          ('27in FHD Monitor', ' LG Dryer'): 4,
#          (' Lightning Charging Cable', ' Google Phone'): 4,
#          ('Vareebadd Phone', ' 27in 4K Gaming Monitor'): 4,
#          ('27in 4K Gaming Monitor', ' 20in Monitor'): 4,
#          ('LG Washing Machine', ' Lightning Charging Cable'): 4,
#          ('LG Washing Machine', ' Bose SoundSport Headphones'): 4,
#          ('AA Batteries (4-pack)', ' LG Dryer'): 4,
#          ('Vareebadd Phone', ' AAA Batteries (4-pack)'): 4,
#          ('iPhone', ' 20in Monitor'): 4,
#          ('20in Monitor', ' Google Phone'): 4,
#          ('Flatscreen TV', ' ThinkPad Laptop'): 4,
#          ('ThinkPad Laptop', ' 27in FHD Monitor'): 4,
#          ('27in FHD Monitor', ' Flatscreen TV'): 4,
#          ('Google Phone', ' 20in Monitor'): 4,
#          (' Lightning Charging Cable',
#           ' Apple Airpods Headphones',
#           ' Wired Headphones'): 4,
#          ('iPhone', ' Apple Airpods Headphones', ' AAA Batteries (4-pack)'): 3,
#          ('iPhone',
#           ' Lightning Charging Cable',
#           ' Lightning Charging Cable'): 3,
#          ('iPhone', ' Lightning Charging Cable', ' AA Batteries (4-pack)'): 3,
#          ('Google Phone',
#           ' USB-C Charging Cable',
#           ' AAA Batteries (4-pack)'): 3,
#          ('Google Phone',
#           ' USB-C Charging Cable',
#           ' AA Batteries (4-pack)'): 3,
#          ('iPhone', ' Lightning Charging Cable', ' USB-C Charging Cable'): 3,
#          ('27in 4K Gaming Monitor', ' Vareebadd Phone'): 2,
#          (' Lightning Charging Cable', ' Vareebadd Phone'): 2,
#          ('27in FHD Monitor', ' iPhone'): 2,
#          ('Vareebadd Phone', ' Lightning Charging Cable'): 2,
#          ('Google Phone', ' Vareebadd Phone'): 2,
#          (' USB-C Charging Cable', ' Vareebadd Phone'): 2,
#          ('20in Monitor', ' iPhone'): 2,
#          ('LG Dryer', ' Vareebadd Phone'): 2,
#          ('Macbook Pro Laptop', ' Flatscreen TV'): 2,
#          ('ThinkPad Laptop', ' Vareebadd Phone'): 2,
#          (' USB-C Charging Cable', ' 34in Ultrawide Monitor'): 2,
#          (' Bose SoundSport Headphones', ' 34in Ultrawide Monitor'): 2,
#          ('Google Phone', ' Flatscreen TV'): 2,
#          (' Lightning Charging Cable', ' iPhone'): 2,
#          ('LG Washing Machine', ' Google Phone'): 2,
#          ('LG Washing Machine', ' Wired Headphones'): 2,
#          (' Apple Airpods Headphones', ' Google Phone'): 2,
#          (' Wired Headphones', ' Google Phone'): 2,
#          (' Wired Headphones', ' 27in 4K Gaming Monitor'): 2,
#          ('LG Dryer', ' Flatscreen TV'): 2,
#          ('27in FHD Monitor', ' LG Washing Machine'): 2,
#          ('LG Dryer', ' 27in FHD Monitor'): 2,
#          ('20in Monitor', ' 34in Ultrawide Monitor'): 2,
#          (' Wired Headphones', ' Wired Headphones'): 2,
#          (' Wired Headphones', ' Macbook Pro Laptop'): 2,
#          ('34in Ultrawide Monitor', ' 20in Monitor'): 2,
#          (' Wired Headphones', ' 27in FHD Monitor'): 2,
#          ('34in Ultrawide Monitor', ' LG Washing Machine'): 2,
#          ('Google Phone', ' 27in 4K Gaming Monitor'): 2,
#          ('LG Washing Machine', ' iPhone'): 2,
#          ('LG Dryer', ' Wired Headphones'): 2,
#          (' Lightning Charging Cable', ' 34in Ultrawide Monitor'): 2,
#          (' Bose SoundSport Headphones', ' 27in FHD Monitor'): 2,
#          (' Lightning Charging Cable', ' 27in 4K Gaming Monitor'): 2,
#          ('27in FHD Monitor', ' Vareebadd Phone'): 2,
#          ('LG Washing Machine', ' 27in 4K Gaming Monitor'): 2,
#          (' Apple Airpods Headphones', ' Bose SoundSport Headphones'): 2,
#          ('LG Washing Machine', ' Apple Airpods Headphones'): 2,
#          ('27in 4K Gaming Monitor', ' LG Dryer'): 2,
#          ('20in Monitor', ' LG Washing Machine'): 2,
#          ('LG Dryer', ' Google Phone'): 2,
#          ('Vareebadd Phone', ' 27in FHD Monitor'): 2,
#          ('ThinkPad Laptop', ' 27in 4K Gaming Monitor'): 2,
#          ('20in Monitor', ' Flatscreen TV'): 2,
#          ('USB-C Charging Cable', ' LG Dryer'): 2,
#          (' Wired Headphones', ' Lightning Charging Cable'): 2,
#          (' Bose SoundSport Headphones', ' Apple Airpods Headphones'): 2,
#          ('LG Washing Machine', ' 20in Monitor'): 2,
#          ('Flatscreen TV', ' 20in Monitor'): 2,
#          ('27in FHD Monitor', ' Google Phone'): 2,
#          ('iPhone', ' 27in FHD Monitor'): 2,
#          (' USB-C Charging Cable', ' Lightning Charging Cable'): 2,
#          (' Lightning Charging Cable', ' AAA Batteries (4-pack)'): 2,
#          ('LG Dryer', ' AAA Batteries (4-pack)'): 2,
#          ('ThinkPad Laptop', ' 34in Ultrawide Monitor'): 2,
#          ('iPhone', ' LG Washing Machine'): 2,
#          (' Bose SoundSport Headphones', ' Lightning Charging Cable'): 2,
#          (' Bose SoundSport Headphones', ' Flatscreen TV'): 2,
#          (' Lightning Charging Cable', ' Flatscreen TV'): 2,
#          ('AAA Batteries (4-pack)', ' LG Dryer'): 2,
#          ('LG Dryer', ' 27in 4K Gaming Monitor'): 2,
#          ('LG Dryer', ' Lightning Charging Cable'): 2,
#          ('ThinkPad Laptop', ' LG Dryer'): 2,
#          ('LG Washing Machine', ' AA Batteries (4-pack)'): 2,
#          ('Google Phone', ' USB-C Charging Cable', ' USB-C Charging Cable'): 2,
#          ('Google Phone', ' Wired Headphones', ' USB-C Charging Cable'): 2,
#          ('Google Phone', ' USB-C Charging Cable', ' 27in FHD Monitor'): 2,
#          ('Google Phone',
#           ' USB-C Charging Cable',
#           ' Apple Airpods Headphones'): 2,
#          ('iPhone', ' Lightning Charging Cable', ' Google Phone'): 2,
#          ('Google Phone', ' Wired Headphones', ' AA Batteries (4-pack)'): 2,
#          (' USB-C Charging Cable',
#           ' Wired Headphones',
#           ' USB-C Charging Cable'): 1,
#          ('iPhone', ' Lightning Charging Cable', ' Vareebadd Phone'): 1,
#          ('Google Phone', ' USB-C Charging Cable', ' Vareebadd Phone'): 1,
#          ('iPhone', ' Wired Headphones', ' AA Batteries (4-pack)'): 1,
#          (' Lightning Charging Cable',
#           ' Wired Headphones',
#           ' AA Batteries (4-pack)'): 1,
#          ('Vareebadd Phone', ' USB-C Charging Cable', ' iPhone'): 1,
#          ('Google Phone',
#           ' USB-C Charging Cable',
#           ' 34in Ultrawide Monitor'): 1,
#          ('Google Phone',
#           ' Bose SoundSport Headphones',
#           ' 34in Ultrawide Monitor'): 1,
#          (' USB-C Charging Cable',
#           ' Bose SoundSport Headphones',
#           ' 34in Ultrawide Monitor'): 1,
#          ('Google Phone', ' Wired Headphones', ' Apple Airpods Headphones'): 1,
#          (' USB-C Charging Cable',
#           ' Wired Headphones',
#           ' Apple Airpods Headphones'): 1,
#          ('iPhone', ' Lightning Charging Cable', ' iPhone'): 1,
#          ('Vareebadd Phone', ' Wired Headphones', ' iPhone'): 1,
#          ('Vareebadd Phone',
#           ' Wired Headphones',
#           ' Apple Airpods Headphones'): 1,
#          ('iPhone', ' Apple Airpods Headphones', ' Google Phone'): 1,
#          ('iPhone', ' Wired Headphones', ' Google Phone'): 1,
#          (' Lightning Charging Cable',
#           ' Apple Airpods Headphones',
#           ' Google Phone'): 1,
#          (' Lightning Charging Cable',
#           ' Wired Headphones',
#           ' Google Phone'): 1,
#          (' Apple Airpods Headphones',
#           ' Wired Headphones',
#           ' Google Phone'): 1,
#          ('Vareebadd Phone',
#           ' Wired Headphones',
#           ' 27in 4K Gaming Monitor'): 1,
#          ('Google Phone', ' Wired Headphones', ' Wired Headphones'): 1,
#          (' USB-C Charging Cable',
#           ' Wired Headphones',
#           ' Wired Headphones'): 1,
#          ('Google Phone', ' Wired Headphones', ' Macbook Pro Laptop'): 1,
#          ('Google Phone', ' Wired Headphones', ' 27in FHD Monitor'): 1,
#          (' USB-C Charging Cable',
#           ' Wired Headphones',
#           ' 27in FHD Monitor'): 1,
#          ('iPhone', ' Lightning Charging Cable', ' 34in Ultrawide Monitor'): 1,
#          ('Google Phone',
#           ' Bose SoundSport Headphones',
#           ' 27in FHD Monitor'): 1,
#          ('iPhone', ' Lightning Charging Cable', ' 27in 4K Gaming Monitor'): 1,
#          (' USB-C Charging Cable',
#           ' Wired Headphones',
#           ' AA Batteries (4-pack)'): 1,
#          ('iPhone',
#           ' Apple Airpods Headphones',
#           ' Bose SoundSport Headphones'): 1,
#          ('iPhone', ' Wired Headphones', ' USB-C Charging Cable'): 1,
#          (' Lightning Charging Cable',
#           ' Wired Headphones',
#           ' USB-C Charging Cable'): 1,
#          ('iPhone', ' Wired Headphones', ' Lightning Charging Cable'): 1,
#          ('Google Phone',
#           ' Bose SoundSport Headphones',
#           ' Apple Airpods Headphones'): 1,
#          ('Vareebadd Phone',
#           ' USB-C Charging Cable',
#           ' Apple Airpods Headphones'): 1,
#          ('Google Phone',
#           ' USB-C Charging Cable',
#           ' Lightning Charging Cable'): 1,
#          ('iPhone', ' Lightning Charging Cable', ' AAA Batteries (4-pack)'): 1,
#          ('Google Phone',
#           ' Bose SoundSport Headphones',
#           ' Lightning Charging Cable'): 1,
#          ('Vareebadd Phone',
#           ' Bose SoundSport Headphones',
#           ' Flatscreen TV'): 1,
#          ('iPhone', ' Lightning Charging Cable', ' Flatscreen TV'): 1,
#          ('Google Phone', ' USB-C Charging Cable', ' iPhone'): 1,
#          ('Google Phone', ' Wired Headphones', ' iPhone'): 1,
#          (' USB-C Charging Cable', ' Wired Headphones', ' iPhone'): 1})

# %%
count.most_common(10)
# Out:
# [(('Google Phone', ' USB-C Charging Cable'), 9110),
#  (('iPhone', ' Lightning Charging Cable'), 2010),
#  (('iPhone', ' Wired Headphones'), 894),
#  (('Google Phone', ' Wired Headphones'), 828),
#  (('Vareebadd Phone', ' USB-C Charging Cable'), 722),
#  (('iPhone', ' Apple Airpods Headphones'), 720),
#  (('Google Phone', ' Bose SoundSport Headphones'), 440),
#  (('Vareebadd Phone', ' Wired Headphones'), 286),
#  ((' USB-C Charging Cable', ' Wired Headphones'), 240),
#  (('Vareebadd Phone', ' Bose SoundSport Headphones'), 160)]

# %%
result=amd.groupby('Product')['Quantity Ordered'].sum()

# %%
result
# Out:
# Product
# 20in Monitor                   4129
# 27in 4K Gaming Monitor         6244
# 27in FHD Monitor               7550
# 34in Ultrawide Monitor         6199
# AA Batteries (4-pack)         27635
# AAA Batteries (4-pack)        31017
# Apple Airpods Headphones      15661
# Bose SoundSport Headphones    13457
# Flatscreen TV                  4819
# Google Phone                   5532
# LG Dryer                        646
# LG Washing Machine              666
# Lightning Charging Cable      23217
# Macbook Pro Laptop             4728
# ThinkPad Laptop                4130
# USB-C Charging Cable          23975
# Vareebadd Phone                2068
# Wired Headphones              20557
# iPhone                         6849
# Name: Quantity Ordered, dtype: int32

# %%
products=[item for item,k in amd.groupby('Product')]

# %%
products
# Out:
# ['20in Monitor',
#  '27in 4K Gaming Monitor',
#  '27in FHD Monitor',
#  '34in Ultrawide Monitor',
#  'AA Batteries (4-pack)',
#  'AAA Batteries (4-pack)',
#  'Apple Airpods Headphones',
#  'Bose SoundSport Headphones',
#  'Flatscreen TV',
#  'Google Phone',
#  'LG Dryer',
#  'LG Washing Machine',
#  'Lightning Charging Cable',
#  'Macbook Pro Laptop',
#  'ThinkPad Laptop',
#  'USB-C Charging Cable',
#  'Vareebadd Phone',
#  'Wired Headphones',
#  'iPhone']

# %%
plt.bar(products,result)
plt.xticks(products,rotation='vertical')
plt.xlabel('Products')
plt.ylabel('No. sold')
# Out:
# Text(0, 0.5, 'No. sold')

# %%
prices=amd.groupby('Product')['Price Each'].mean()
fig,ax1=plt.subplots()
ax2=ax1.twinx()
ax1.bar(products,result,color='g')
ax2.plot(products,prices,color='r')
ax1.set_xlabel('Product Name')
ax1.set_xticklabels(products,rotation='vertical')
ax1.set_ylabel('Quantity Ordered')
ax2.set_ylabel('Price($)')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_9036\67176834.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(products,rotation='vertical')
# Text(0, 0.5, 'Price($)')

# %%
amd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 185950 entries, 0 to 11685
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int32
#  3   Price Each        185950 non-null  float32
#  4   Order Date        185950 non-null  datetime64[ns]
#  5   Purchase Address  185950 non-null  object
#  6   Month             185950 non-null  int32
#  7   Sales             185950 non-null  float64
#  8   City              185950 non-null  object
#  9   Hours             185950 non-null  int32
# dtypes: datetime64[ns](1), float32(1), float64(1), int32(3), object(4)
# memory usage: 12.8+ MB
